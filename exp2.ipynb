# %%
str1='dkte'
str2="dkte"
str3='''dkte'''
str4="10"
print (type(str3))
# Out:
# <class 'str'>

# %%
str1="dkte"
str2="college"
print(str1+str2)
print(str1+' ' +str2)
# Out:
# dktecollege
# dkte college

# %%
str1='dkte'
str2="dkte college"
print(len(str1))
print (len(str2))
# Out:
# 4
# 12

# %%
str1="HELLO"
print(str1[1])
print(str1[0])
print(str1[2])
print(str1[6])
# Out:
# E
# H
# L
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 5
#       3 print(str1[0])
#       4 print(str1[2])
# ----> 5 print(str1[6])
#
# IndexError: string index out of range

# %%
str1='dkte'
print(str1[1:3])
print(str1[0:3])
print(str1[ :3])
print(str1[1: ])
print(str1[ : ])
# Out:
# kt
# dkt
# dkt
# kte
# dkte

# %%
str1='dkte'
print(str1.startswith('D'))
print(str1.startswith('d'))
# Out:
# False
# True

# %%
str1='dkte'
print(str1.endswith('e'))
print(str1.endswith('t'))
# Out:
# True
# False

# %%
str1="Dkte college"
print(str1.istitle())
# Out:
# False

# %%
str2="DKTE"
print(str2.isupper())
# Out:
# True

# %%
str3="dkte"
print(str3.islower())
# Out:
# True

# %%
str5="dkte"
print(str5.upper())
str6="DKTE"
print(str6.lower())
# Out:
# DKTE
# dkte

# %%
str1="Ichalkaranji"
print(str1.find('a'))
# Out:
# 3

# %%
str1="Ichalkaranji"
print(str1.count('a'))
# Out:
# 3

# %%
str7="Ichalkaranji"
print(str7.replace('a','k'))
# Out:
# Ichklkkrknji
